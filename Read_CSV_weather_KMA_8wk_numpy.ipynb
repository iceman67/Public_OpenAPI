# %%
import csv

# %%
with open('400_20200411221745769.csv', 'r') as file:
    reader = csv.reader(file)
    next(reader)
    line = []
    for row in reader:
        line.append(row)
        #print(row)

# %%
len(line)
# Out:
# 8796

# %%
line[1]
# Out:
# [' 1', ' 0100', ' 8.800000 ']

# %%
count  = 0
no_row = len(line)
error = 0
s = 0
temp =[]
while count < no_row:
    if len(line[count]) == 3: 
        temp.append(float(line[count][2]))
        s = s + float(line[count][2])
    else:
        error = error + 1
    count = count + 1

# %%
temp[5]
# Out:
# 8.4

# %%
print ("averge = {:f}".format(s/(count-error)))
print ("error = {}".format(error))
# Out:
# averge = 12.549966
# error = 12

# %%
print ("max = {}".format(max(temp)))
print ("min = {}".format(min(temp)))
# Out:
# max = 36.700001
# min = -50.0

# %%
count  = 0
no_row = len(line)
temp = []
while count < no_row:
    if len(line[count]) == 3: 
        temp.append( float(line[count][2]))
    count = count + 1

# %%
print ("max = {}".format(max(temp)))
print ("min = {}".format(min(temp)))
print ("averge = {:f}".format(avg(temp, error)))

# %% [markdown]
# numpy를 사용하여 고속데이터 처리하기

# %%
import numpy as np

# %%
ar = np.array(temp)
print(ar.shape)
print(ar.dtype)
# Out:
# (8784,)
# float64

# %% [markdown]
# 벡터화 연산

# %%
max = ar.max() 
min = ar.min() 
avg = np.average(ar)
print("최대값:{}\n최소값:{}\n평균값:{}".format(max,min,avg))
# Out:
# 최대값:36.700001
# 최소값:-50.0
# 평균값:12.549965844034606

# %%
ar = [i  for i in ar if i > -20]

# %%
import numpy as np  #  arrays and matrices
import matplotlib.pyplot as plt 


x = np.arange(len(ar)) 
plt.plot(x, ar, ':b', color='g')
plt.xlim(0, 5)
plt.ylim(15, 50);
plt.axis('tight');
plt.title("KMA weather")
plt.ylabel("Temp");

plt.show()

# %% [markdown]
# List 사용한 플롯팅

# %%
import matplotlib.pyplot as plt

# %%
x = list(range(len(temp)))

# %%
plt.plot(x, temp, ':b', color='g')
plt.xlim(0, 5)
plt.ylim(15, 50);
plt.axis('tight');
plt.title("OpenweatherMap")
plt.ylabel("Temp");

plt.show()

# %%
temp = [i  for i in temp if i > -20]

# %%
x = list(range(len(temp)))

# %%
plt.plot(x, temp, ':b', color='b')
plt.xlim(0, 5)
plt.ylim(15, 50);
plt.axis('tight');
plt.title("OpenweatherMap")
plt.ylabel("Temp");

plt.show()
